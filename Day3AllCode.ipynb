# %% [markdown]
# <a href="https://colab.research.google.com/github/Maew007/Emotion-recognition/blob/master/Day3AllCode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

# %%
im = mpimg.imread('/content/koala.JPG')

# %%
plt.imshow(im)

# %%
plt.imshow(im[:,:,0])

# %%
plt.imshow(im[:,:,1])

# %%
plt.imshow(im[:,:,2])

# %%
plt.subplot(141)
plt.title("OMG image")
plt.imshow(im)
plt.subplot(142)
plt.title("Tone Green")
plt.imshow(im[:,:,0])
plt.subplot(143)
plt.title("Tone Blue")
plt.imshow(im[:,:,1])
plt.subplot(144)
plt.title("Tone Red")
plt.imshow(im[:,:,2])

# %%
plt.subplot(141)
plt.title("OMG image")
plt.imshow(im)
plt.subplot(142)
plt.title("Tone Green")
plt.imshow(im[40:80,60:100,0])

# %% [markdown]
# # **เริ่มต้นบทเรียน DAY3 เรื่อง ข้อมูลภาพ และการประมวลผลเบื้องต้น **

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg

# %% [markdown]
# เป็นคำสั่งที่ใช้เพื่ออ่านไฟล์ข้อมูลรูปภาพเข้ามาเก็บไว้ในตัวแปรชื่อ img

# %%
img_cv = cv.imread('/content/koala.JPG')

# %% [markdown]
# img.shape หมายถึงการ อ่านข้อมูล Size ของภาพ
# 1.   จำนวน Pixel แกน X มีค่าเท่ากับ 301
# 2.   จำนวน Pixel แกน y มีค่าเท่ากับ 220
# 3.   มีจำนวนมิติ เท่ากับ 3 มิติ แบ่งเป็นภาพ
#
# *   โทนสีเงิน
# *   โทนสีเขียว
# *   โทนสีแดง

# %%
print(img_cv.shape)
# Out:
# (301, 220, 3)

# %% [markdown]
# คำสั่งที่ใช้เพื่อทำแปลงข้อมูลภาพ สี Blue,Green,Red ไปเป็นภาพขนาดสองมิติ เป็ภาพโทนเทา
#
#
# img = (in_img.sum(axis = 2)[:,:,None]/3*np.array([1,1,1])).astype('uint8')

# %%
img_gray = cv.cvtColor(img_cv, cv.COLOR_BGR2GRAY)

# %%
print(img_gray.shape)
# Out:
# (301, 220)

# %%
plt.subplot(121)
plt.title("ORG image BGR")
plt.imshow(img_cv)
plt.subplot(122)
plt.title("Gray")
plt.imshow(img_gray)

# %%
  im_a = cv.flip(img_cv,1)

# %%
plt.imshow(im_a)

# %%
newX = 50
newY = 50
newsize_img = cv2.resize(img_cv,(int(newX),int(newY)))

# %%
plt.imshow(newsize_img)
print(newsize_img.shape)
# Out:
# (50, 50, 3)

# %%
(h, w) = img_cv.shape[:2]
center = (w / 2, h / 2)

# %%
angle90 = 90
angle180 = 180
angle270 = 270
 
scale = 1.0

# %%
M = cv2.getRotationMatrix2D(center, angle90, scale)
rotated90 = cv2.warpAffine(img_cv, M, (h, w))

# %%
plt.imshow(rotated90)
